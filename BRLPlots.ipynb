# %%
import arviz
import numpy as np
import numba
import matplotlib.pyplot as plt
from scipy.spatial.distance import hamming
from time import time

#Import the helper functions and all the samplers
from BasicFunctions import *
from TabuSampler import tabu_sampler
from ZanellaSampler import zanella_sampler
from RandomWalkSampler import rw_sampler
from PointwiseSampler import pointwise_sampler 

#Autocorrelation function as implemented by Power and Goldman
@numba.njit()
def autocorr(x, lags):
    mean=np.mean(x)
    var=np.var(x)
    xp=x-mean
    corr=[1. if l==0 else np.sum(xp[l:]*xp[:-l])/len(x)/var for l in lags]
    return np.array(corr)

# %%
#Defining the Barker balancing functions
g = lambda t: t/(1+t)

# %%
## First plot ESS of all samplers compared for different beta values

#Some global parameters used
lmbd = 50
l = 15 #The number of categories for each record
p_cat = np.array([0.05, 0.15, 0.4, 0.2, 0.2]) #The pval vector for each category

#Parameters for the simulation
num_beta = 5
num_avg = 5
beta_array = np.array([0.01, 0.05, 0.10, 0.20, 0.30])
ESS_time_array = np.zeros((4,5))

#Simulation parameters
T_z = 30
thin_rate_z = 0.015
T_t = 60
thin_rate_t = 0.03
N = 2000


for b in np.arange(0, num_beta):
    #The chosen beta value
    beta = beta_array[b]
    
    #The placeholder array for each sampler
    results_iter = np.zeros((4,5))
    
    for iter in np.arange(0, num_avg):
        #Creating the sampling arrays
        p_match, x, y, M_truth, M_reverse_truth = create_databases(lmbd, l, p_cat, beta)
        N_1 = len(x)
        N_2 = len(y)
        num_gens = N_1*N_2

        #The starting state
        M_initial, M_reverse_initial = random_state(N_1, N_2)
        
        #Running each of the simulators and save the results
        #Random walk
        trace, energy, hamming, num_acc, runtime = rw_sampler(N, N_1, N_2, lmbd, p_match, M_truth, M_initial, M_reverse_initial,
                                                              p_cat, l, beta, x, y, print_rate=10)
        
        ESS_runtime = arviz.ess(hamming)/runtime
        results_iter[0, iter] = ESS_runtime
        
        #Pointwise sampler
        trace, energy, hamming, num_acc, runtime = pointwise_sampler(N, N_1, N_2, lmbd, p_match, g, M_truth, M_initial, 
                                                                     M_reverse_initial, p_cat, l, beta, x, y, print_rate=10)
        
        ESS_runtime = arviz.ess(hamming)/runtime
        results_iter[1, iter] = ESS_runtime
        
        #Zanella sampler
        trace, energy, hamming, num_iter, runtime = zanella_sampler(N_1, N_2, num_gens, M_initial, M_reverse_initial, g, T_z, M_truth, thin_rate_z, 10, lmbd, 
                                                                    p_match, l, p_cat, beta, x, y)
        
        
        ESS_runtime = arviz.ess(hamming)/runtime
        results_iter[2, iter] = ESS_runtime
        
        #Tabu sampler
        trace, energy, hamming, alpha, num_iter, runtime = tabu_sampler(N_1, N_2, num_gens, M_initial, M_reverse_initial, g, T_t, M_truth, thin_rate_t,
                                                                        10, lmbd, p_match, l, p_cat, beta, x, y)
        
        ESS_runtime = arviz.ess(hamming)/runtime
        results_iter[3, iter] = ESS_runtime
        
    #Taking the average over the 5 runs and put that into the result array
    ESS_time_array[0, b] = np.mean(results_iter[0,:])
    ESS_time_array[1, b] = np.mean(results_iter[1,:])
    ESS_time_array[2, b] = np.mean(results_iter[2,:])
    ESS_time_array[3, b] = np.mean(results_iter[3,:])
    
#Printing the final result
print("---------------------------------------------------")
print("The final array:")
print(ESS_time_array)
print("---------------------------------------------------")
# Out:
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.073
# Runtime:  7.18
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.9995
# Runtime:  70.82
# Runtime:  6.51
# Average excursion length:  1.0
# Runtime:  6.18
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.038
# Runtime:  5.62
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.5015
# Runtime:  60.49
# Runtime:  8.0
# Average excursion length:  1.0
# Runtime:  8.03
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.04
# Runtime:  5.2
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  1.0
# Runtime:  77.92
# Runtime:  10.68
# Percent: [--------------------------------------> ] 97%Average excursion length:  1.0
# Runtime:  10.34
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.032
# Runtime:  6.26
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.999
# Runtime:  63.16
# Runtime:  4.74
# Percent: [--------------------------------------->] 101%Average excursion length:  1.0
# Runtime:  5.28
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.03
# Runtime:  3.89
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.5005
# Runtime:  32.07
# Runtime:  3.0
# Average excursion length:  1.0
# Runtime:  3.4
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.027
# Runtime:  3.85
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.514
# Runtime:  36.62
# Percent: [------------------------->              ] 64%Runtime:  4.05
# Percent: [----------------------------------->    ] 91%Average excursion length:  2.0
# Runtime:  3.97
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.045
# Runtime:  3.47
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.9995
# Runtime:  33.69
# Runtime:  2.26
# Average excursion length:  1.0
# Runtime:  2.55
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.0415
# Runtime:  5.15
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.9895
# Runtime:  70.21
# Runtime:  7.13
# Percent: [--------------------------------->      ] 86%Average excursion length:  1.0
# Runtime:  7.43
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.0405
# Runtime:  4.05
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.5005
# Runtime:  29.1
# Runtime:  3.16
# Average excursion length:  1.0
# Runtime:  2.79
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.0175
# Runtime:  5.53
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.4835
# Runtime:  34.29
# Runtime:  3.11
# Average excursion length:  1.0
# Runtime:  2.95
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.0595
# Runtime:  5.79
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.468
# Runtime:  50.66
# Runtime:  5.72
# Percent: [------------------------------------->  ] 94%Average excursion length:  2.0
# Runtime:  3.89
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.0045
# Runtime:  1.1
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.4995
# Runtime:  20.0
# Percent: [---------------------------------------------->] 116%Runtime:  0.53
# Average excursion length:  1.0
# Runtime:  0.35
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.052
# Runtime:  3.51
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.896
# Runtime:  36.65
# Runtime:  2.36
# Average excursion length:  1.0
# Runtime:  1.69
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.0155
# Runtime:  5.65
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.487
# Runtime:  55.33
# Runtime:  5.91
# Percent: [--------------------------------------->] 100%Average excursion length:  5.0
# Runtime:  8.96
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.0115
# Runtime:  3.32
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.5105
# Runtime:  43.14
# Percent: [--------------------------------------->] 99%Runtime:  5.06
# Percent: [-------------------------------->       ] 83%Average excursion length:  2.0
# Runtime:  4.52
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.111
# Runtime:  10.42
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.7875
# Runtime:  149.82
# Percent: [--------------------------------------> ] 98%Runtime:  33.31
# Percent: [--------------------------------------> ] 98%Average excursion length:  7.0
# Runtime:  32.23
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.05
# Runtime:  5.36
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.588
# Runtime:  52.98
# Percent: [--------------------------------------->] 100%Runtime:  58.51
# Percent: [--------------------------------------->] 100%Average excursion length:  12.0
# Runtime:  56.31
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.089
# Runtime:  9.83
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.6845
# Runtime:  97.55
# Percent: [--------------------------------------> ] 97%Runtime:  19.09
# Percent: [--------------------------------------> ] 96%Average excursion length:  6.0
# Runtime:  25.67
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.015
# Runtime:  3.26
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.6635
# Runtime:  46.45
# Percent: [--------------------------------------->] 100%Runtime:  27.75
# Percent: [--------------------------------------> ] 98%Average excursion length:  10.0
# Runtime:  28.67
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.0445
# Runtime:  3.53
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.594
# Runtime:  28.2
# Percent: [--------------------------------------->] 99%Runtime:  41.96
# Percent: [--------------------------------------->] 100%Average excursion length:  13.0
# Runtime:  52.28
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.098
# Runtime:  9.27
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.6935
# Runtime:  96.22
# Percent: [--------------------------------------->] 100%Runtime:  56.11
# Percent: [--------------------------------------->] 100%Average excursion length:  13.0
# Runtime:  69.89
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.135
# Runtime:  10.72
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.7695
# Runtime:  142.41
# Percent: [--------------------------------------->] 100%Runtime:  57.7
# Percent: [--------------------------------------->] 100%Average excursion length:  13.0
# Runtime:  51.92
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.022
# Runtime:  3.25
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.63
# Runtime:  32.24
# Percent: [--------------------------------------->] 100%Runtime:  32.94
# Percent: [--------------------------------------->] 100%Average excursion length:  12.0
# Runtime:  38.96
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.126
# Runtime:  11.81
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.7395
# Runtime:  136.63
# Percent: [--------------------------------------->] 99%Runtime:  66.78
# Percent: [--------------------------------------->] 100%Average excursion length:  15.0
# Runtime:  72.45
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.092
# Runtime:  6.51
# Percent: [--------------------------------------->] 100%
# Acceptance ratio:  0.6815
# Runtime:  58.21
# Percent: [--------------------------------------->] 99%Runtime:  59.65
# Percent: [--------------------------------------->] 99%Average excursion length:  14.0
# Runtime:  58.27
# ---------------------------------------------------
# The final array:
# [[2.35861402e-01 3.09272286e-01 6.48234458e-01 2.61337734e-01
#   5.52941926e-01]
#  [4.78984806e+01 1.04375103e+02 8.62999230e+01 3.83371568e+00
#   1.18769552e+00]
#  [7.39419820e+00 1.35316732e+02 1.12227244e+01 4.70566665e-01
#   4.01999148e-01]
#  [2.82667889e+02 2.10723275e+02 3.77735536e+00 3.63851678e-01
#   4.16452168e-01]]
# ---------------------------------------------------
